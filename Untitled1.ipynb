# %%
import pandas as pd
import matplotlib.pyplot as plt
excel_file = '/Volumes/BRANDT_ECON/Combined_Values.csv'
Combined_Values = pd.read_csv(excel_file)

#plotting individual columns
Combined_Values.plot(kind='scatter',x='Date',y='Close',color='red')
plt.show()
Combined_Values.plot(kind='scatter',x='Date',y='GDP',color='blue')
plt.show()
Combined_Values.plot(kind='scatter',x='Date',y='USD_to_EUR',color='green')
plt.show()
Combined_Values.plot(kind='scatter',x='Date',y='NonFarm_Payroll',color='yellow')
plt.show()
Combined_Values.plot(kind='scatter',x='Date',y='3_month_Libor',color='orange')
plt.show()
Combined_Values.plot(kind='scatter',x='Date',y='Unemployment',color='purple')
plt.show()

#getting data in a range where we have data from all columns
Combined_Values = Combined_Values.drop(Combined_Values.index[0:9]) #gets rid of first N/A
Combined_Values = Combined_Values.drop(Combined_Values.index[1000:17989]) #gets rid of last N/A
Combined_Values.head()
# Out:
#      Date         Open         High          Low        Close    Adj Close  \
# 9   43343  2898.370117  2906.320068  2891.729980  2901.520020  2901.520020
# 10  43342  2908.939941  2912.459961  2895.219971  2901.129883  2901.129883
# 11  43341  2900.620117  2916.500000  2898.399902  2914.040039  2914.040039
# 12  43340  2901.449951  2903.770020  2893.500000  2897.520020  2897.520020
# 13  43339  2884.689941  2898.250000  2884.689941  2896.739990  2896.739990
#
#         Volume  USD_to_EUR        GDP  NonFarm_Payroll  3_month_Libor  \
# 9   2880260000      1.1596  18514.595         149226.0        2.32075
# 10  2802180000      1.1646  18514.595         149226.0        2.32125
# 11  2791860000      1.1699  18514.595         149226.0        2.31263
# 12  2683190000      1.1720  18514.595         149226.0        2.31475
# 13  2854080000      1.1676  18514.595         149226.0        2.31725
#
#     Unemployment
# 9         6370.0
# 10        6370.0
# 11        6370.0
# 12        6370.0
# 13        6370.0

# %%
#plotting everything on the same axis!
plt.clf()
ax = plt.gca()
Combined_Values.plot(kind='scatter',x='Date',y='Close',color='red', ax=ax)
Combined_Values.plot(kind='scatter',x='Date',y='GDP',color='blue',ax=ax)
Combined_Values.plot(kind='scatter',x='Date',y='USD_to_EUR',color='green',ax=ax)
Combined_Values.plot(kind='scatter',x='Date',y='NonFarm_Payroll',color='yellow',ax=ax)
Combined_Values.plot(kind='scatter',x='Date',y='3_month_Libor',color='orange',ax=ax)
Combined_Values.plot(kind='scatter',x='Date',y='Unemployment',color='purple',ax=ax)

# %%
import seaborn as sns
import matplotlib.pyplot as ply

#correlation matrix which shows visually how correlated variables 
#are to each other. See 2nd matrix (below this one) for OLS best fit lines drawn also
sns.pairplot(Combined_Values)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as ply

sns.pairplot(Combined_Values, kind="reg")
plt.show()

# %%
#Source https://stackoverflow.com/questions/29432629/correlation-matrix-using-pandas
#rs = np.random.RandomState(0)
corr = Combined_Values.corr()
corr.style.background_gradient()
#sns.heatmap(Combined_Values.corr(), square = True, cmap='RdYlGn')
# Out:
# <style  type="text/css" >
#     #T_09fe4458_d334_11e8_b094_a82066434457row0_col0 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col1 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col2 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col3 {
#             background-color:  #03466e;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col4 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col5 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col6 {
#             background-color:  #f1ebf4;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col7 {
#             background-color:  #d0d1e6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col8 {
#             background-color:  #02395a;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col9 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col10 {
#             background-color:  #023e62;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row0_col11 {
#             background-color:  #fbf3f9;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col0 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col1 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col2 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col3 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col4 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col5 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col6 {
#             background-color:  #fdf5fa;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col7 {
#             background-color:  #91b5d6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col8 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col9 {
#             background-color:  #034e7b;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col10 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row1_col11 {
#             background-color:  #f4edf6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col0 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col1 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col2 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col3 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col4 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col5 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col6 {
#             background-color:  #fdf5fa;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col7 {
#             background-color:  #8eb3d5;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col8 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col9 {
#             background-color:  #034e7b;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col10 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row2_col11 {
#             background-color:  #f4edf6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col0 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col1 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col2 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col3 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col4 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col5 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col6 {
#             background-color:  #fff7fb;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col7 {
#             background-color:  #93b5d6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col8 {
#             background-color:  #034267;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col9 {
#             background-color:  #034e7b;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col10 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row3_col11 {
#             background-color:  #f4edf6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col0 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col1 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col2 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col3 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col4 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col5 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col6 {
#             background-color:  #fef6fa;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col7 {
#             background-color:  #91b5d6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col8 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col9 {
#             background-color:  #034e7b;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col10 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row4_col11 {
#             background-color:  #f4edf6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col0 {
#             background-color:  #03456c;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col1 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col2 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col3 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col4 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col5 {
#             background-color:  #023858;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col6 {
#             background-color:  #fef6fa;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col7 {
#             background-color:  #91b5d6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col8 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col9 {
#             background-color:  #034e7b;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col10 {
#             background-color:  #034165;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row5_col11 {
#             background-color:  #f4edf6;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row6_col0 {
#             background-color:  #a8bedc;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row6_col1 {
#             background-color:  #c8cde4;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row6_col2 {
#             background-color:  #c6cce3;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row6_col3 {
#             background-color:  #cccfe5;
#         }    #T_09fe4458_d334_11e8_b094_a82066434457row6_col4 {

# %%
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

A = Combined_Values.values
y = A[:, 5]
y = y.reshape(-1,1)
print(type(y))     #we want numpy.ndaray
print(y.shape)     #we want dimensions 1000x1
x = A[:,10]
x = x.reshape(-1,1)

reg = linear_model.LinearRegression()
reg.fit(x,y)
prediction_space = np.linspace(min(x),max(x)).reshape(-1, 1)
plt.scatter(x, y, color='blue')
plt.plot(prediction_space, reg.predict(prediction_space),color='black', linewidth=3)
plt.show()
print("No Split R^2 " + str(reg.score(x, y)))
cv_results = cross_val_score(reg, x, y, cv=5, scoring='r2')
#print(cv_results)
print("5 fold mean R^2 " + str(np.mean(cv_results)))
# Out:
# <class 'numpy.ndarray'>
# (1000, 1)
# No Split R^2 0.8824800586389379
# 5 fold mean R^2 -1.3847711523524726

# %%
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

A = Combined_Values.values
y = A[:, 5]
y = y.reshape(-1,1)
x = A[:,7:]
x = x.reshape(-1,5)

#reg_all = linear_model.LinearRegression()
reg.fit(x,y)
#prediction_space = np.linspace(min(x),max(x)).reshape(-1, 1)
#plt.scatter(x, y, color='blue')
#plt.plot(prediction_space, reg.predict(prediction_space),color='black', linewidth=3)
#plt.show()
print("No Split R^2 " + str(reg.score(x, y)))
cv_results = cross_val_score(reg, x, y, cv=5, scoring='r2')
#print(cv_results)
print("5 fold mean R^2 " + str(np.mean(cv_results)))
#Heres the Coefficents
print(reg.coef_)
# Out:
# No Split R^2 0.9080249539257846
# 5 fold mean R^2 -4.05077217109592
# [[ 6.75661225e+02  5.06619588e-01 -2.87852180e-03  1.00610825e+02
#    2.63057979e-02]]
